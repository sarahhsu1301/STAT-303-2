# %%
import itertools
import time
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('./fundamentals.csv')

# %%
data["Net Income"].describe()
# Out:
# count    1.781000e+03
# mean     1.705517e+09
# std      3.993401e+09
# min     -2.352800e+10
# 25%      3.528200e+08
# 50%      6.860880e+08
# 75%      1.697000e+09
# max      5.339400e+10
# Name: Net Income, dtype: float64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                        0
# Ticker Symbol                     0
# Period Ending                     0
# Accounts Payable                  0
# Accounts Receivable               0
#                                ...
# Total Revenue                     0
# Treasury Stock                    0
# For Year                        173
# Earnings Per Share              219
# Estimated Shares Outstanding    219
# Length: 79, dtype: int64

# %%
data_cleaner = data.copy()
# Dropping columns based off of knowledge and/or null values
data_cleaner.drop(labels=['Unnamed: 0', 'Period Ending', 'For Year', 'Net Income Adjustments', 'Net Income Applicable to Common Shareholders','Net Income-Cont. Operations',
                         'Earnings Before Interest and Tax', 'Earnings Before Tax', 'Misc. Stocks', 'Net Cash Flow', 'Retained Earnings', 'Sale and Purchase of Stock',
                        'Total Liabilities & Equity', 'Treasury Stock', 'Earnings Per Share', 'Estimated Shares Outstanding', 'Cash Ratio', 'Current Ratio', 'Quick Ratio', 'Total Current Liabilities'], axis=1, inplace = True)

# %%
import pandas as pd
from skimpy import clean_columns
data_cleaner = clean_columns(data_cleaner)
data_cleaner.head()
# Out:
# 59 column names have been cleaned
#   ticker_symbol  accounts_payable  accounts_receivable  \
# 0           AAL      3.068000e+09         -222000000.0
# 1           AAL      4.975000e+09          -93000000.0
# 2           AAL      4.668000e+09         -160000000.0
# 3           AAL      5.102000e+09          352000000.0
# 4           AAP      2.409453e+09          -89482000.0
#
#    addl_income_expense_items  after_tax_roe  capital_expenditures  \
# 0              -1.961000e+09           23.0         -1.888000e+09
# 1              -2.723000e+09           67.0         -3.114000e+09
# 2              -1.500000e+08          143.0         -5.311000e+09
# 3              -7.080000e+08          135.0         -6.151000e+09
# 4               6.000000e+05           32.0         -2.711820e+08
#
#    capital_surplus  cash_and_cash_equivalents  changes_in_inventories  \
# 0     4.695000e+09               1.330000e+09                     0.0
# 1     1.059200e+10               2.175000e+09                     0.0
# 2     1.513500e+10               1.768000e+09                     0.0
# 3     1.159100e+10               1.085000e+09                     0.0
# 4     5.202150e+08               5.981110e+08            -260298000.0
#
#    common_stocks  ...  profit_margin  research_and_development  \
# 0    127000000.0  ...            8.0                       0.0
# 1      5000000.0  ...            7.0                       0.0
# 2      7000000.0  ...            7.0                       0.0
# 3      6000000.0  ...           19.0                       0.0
# 4         7000.0  ...            6.0                       0.0
#
#    sales_general_and_admin  short_term_debt_current_portion_of_long_term_debt  \
# 0             1.297700e+10                                       1.419000e+09
# 1             1.291300e+10                                       1.446000e+09
# 2             2.068600e+10                                       1.677000e+09
# 3             2.127500e+10                                       2.231000e+09
# 4             2.440721e+09                                       6.270000e+05
#
#    short_term_investments  total_assets  total_current_assets  total_equity  \
# 0            3.412000e+09  2.351000e+10          7.072000e+09 -7.987000e+09
# 1            8.111000e+09  4.227800e+10          1.432300e+10 -2.731000e+09
# 2            6.309000e+09  4.322500e+10          1.175000e+10  2.021000e+09
# 3            5.864000e+09  4.841500e+10          9.985000e+09  5.635000e+09
# 4            0.000000e+00  4.613814e+09          3.184200e+09  1.210694e+09
#
#    total_liabilities  total_revenue
# 0       2.489100e+10   2.485500e+10
# 1       4.500900e+10   2.674300e+10
# 2       4.120400e+10   4.265000e+10
# 3       4.278000e+10   4.099000e+10
# 4       3.403120e+09   6.205003e+09
#
# [5 rows x 59 columns]

# %%
from sklearn.model_selection import train_test_split
# separate train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    data_cleaner.drop(labels=['ticker_symbol', 'net_income'], axis=1),
    data_cleaner['net_income'],
    test_size=0.20,
    random_state=23)
train = pd.concat([X_train, y_train], axis = 1)

# %%
train["net_income"].describe()
# Out:
# count    1.424000e+03
# mean     1.744167e+09
# std      4.120869e+09
# min     -1.468500e+10
# 25%      3.519500e+08
# 50%      6.917600e+08
# 75%      1.711000e+09
# max      5.339400e+10
# Name: net_income, dtype: float64

# %%
plt.figure(figsize=(8,5))
ax = sns.boxplot(x = 'net_income', data = train)

# %%
train.corrwith(train['net_income']).abs().sort_values(ascending = False)
# Out:
# net_income                                           1.000000
# operating_income                                     0.915662
# income_tax                                           0.890645
# net_cash_flow_operating                              0.827232
# gross_profit                                         0.775077
# total_revenue                                        0.707769
# total_equity                                         0.705667
# sales_general_and_admin                              0.618690
# total_current_assets                                 0.603381
# depreciation                                         0.600202
# accounts_payable                                     0.577577
# cost_of_revenue                                      0.531961
# capital_expenditures                                 0.520046
# net_receivables                                      0.516953
# net_cash_flows_investing                             0.500887
# other_current_assets                                 0.496438
# research_and_development                             0.463999
# total_assets                                         0.452610
# equity_earnings_loss_unconsolidated_subsidiary       0.443913
# fixed_assets                                         0.443802
# goodwill                                             0.419510
# short_term_investments                               0.413655
# investments                                          0.413092
# total_liabilities                                    0.407477
# deferred_liability_charges                           0.404966
# long_term_debt                                       0.394655
# long_term_investments                                0.372885
# addl_income_expense_items                            0.372451
# common_stocks                                        0.366600
# cash_and_cash_equivalents                            0.364733
# other_current_liabilities                            0.349881
# capital_surplus                                      0.335561
# short_term_debt_current_portion_of_long_term_debt    0.310707
# other_operating_items                                0.289986
# interest_expense                                     0.285527
# intangible_assets                                    0.265092
# inventory                                            0.256302
# other_equity                                         0.245323
# minority_interest                                    0.236089
# other_financing_activities                           0.208624
# net_borrowings                                       0.206143
# other_assets                                         0.172474
# effect_of_exchange_rate                              0.161796
# changes_in_inventories                               0.142662
# deferred_asset_charges                               0.125531
# liabilities                                          0.113030
# other_liabilities                                    0.091760
# operating_margin                                     0.051347
# net_cash_flows_financing                             0.050867
# accounts_receivable                                  0.040553
# non_recurring_items                                  0.035623
# other_investing_activities                           0.033158
# gross_margin                                         0.027956
# pre_tax_margin                                       0.016968
# pre_tax_roe                                          0.016707
# after_tax_roe                                        0.016236
# profit_margin                                        0.011353
# other_operating_activities                           0.001003
# dtype: float64

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x='operating_income',y='net_income',data=train);

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x='income_tax',y='net_income',data=train);

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x='net_cash_flow_operating',y='net_income',data=train);

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x='gross_profit',y='net_income',data=train);

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x='total_revenue',y='net_income',data=train);

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x='depreciation',y='net_income',data=train);

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x='long_term_debt',y='net_income',data=train);

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(x='accounts_receivable',y='net_income',data=train);
