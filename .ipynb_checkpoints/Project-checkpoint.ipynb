# %% [raw]
# ---
# format:
#     html:
#         embed-resources: true
# ---

# %%
import itertools
import time
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('./fundamentals.csv')
data.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# 2         -5.311000e+09     1.513500e+10        60.0  ...
# 3         -6.151000e+09     1.159100e+10        51.0  ...
# 4         -2.711820e+08     5.202150e+08        23.0  ...
#
#    Total Current Assets  Total Current Liabilities  Total Equity  \
# 0          7.072000e+09               9.011000e+09 -7.987000e+09
# 1          1.432300e+10               1.380600e+10 -2.731000e+09
# 2          1.175000e+10               1.340400e+10  2.021000e+09
# 3          9.985000e+09               1.360500e+10  5.635000e+09
# 4          3.184200e+09               2.559638e+09  1.210694e+09
#
#    Total Liabilities  Total Liabilities & Equity  Total Revenue  \
# 0       2.489100e+10                1.690400e+10   2.485500e+10
# 1       4.500900e+10                4.227800e+10   2.674300e+10
# 2       4.120400e+10                4.322500e+10   4.265000e+10
# 3       4.278000e+10                4.841500e+10   4.099000e+10
# 4       3.403120e+09                4.613814e+09   6.205003e+09
#
#    Treasury Stock  For Year  Earnings Per Share  Estimated Shares Outstanding
# 0    -367000000.0    2012.0               -5.60                  3.350000e+08
# 1             0.0    2013.0              -11.25                  1.630222e+08
# 2             0.0    2014.0                4.02                  7.169154e+08
# 3             0.0    2015.0               11.39                  6.681299e+08
# 4     -27095000.0    2012.0                5.29                  7.328355e+07
#
# [5 rows x 79 columns]

# %%
data.columns
# Out:
# Index(['Ticker Symbol', 'Period Ending', 'Accounts Payable',
#        'Accounts Receivable', 'Add'l income/expense items', 'After Tax ROE',
#        'Capital Expenditures', 'Capital Surplus', 'Cash Ratio',
#        'Cash and Cash Equivalents', 'Changes in Inventories', 'Common Stocks',
#        'Cost of Revenue', 'Current Ratio', 'Deferred Asset Charges',
#        'Deferred Liability Charges', 'Depreciation',
#        'Earnings Before Interest and Tax', 'Earnings Before Tax',
#        'Effect of Exchange Rate',
#        'Equity Earnings/Loss Unconsolidated Subsidiary', 'Fixed Assets',
#        'Goodwill', 'Gross Margin', 'Gross Profit', 'Income Tax',
#        'Intangible Assets', 'Interest Expense', 'Inventory', 'Investments',
#        'Liabilities', 'Long-Term Debt', 'Long-Term Investments',
#        'Minority Interest', 'Misc. Stocks', 'Net Borrowings', 'Net Cash Flow',
#        'Net Cash Flow-Operating', 'Net Cash Flows-Financing',
#        'Net Cash Flows-Investing', 'Net Income', 'Net Income Adjustments',
#        'Net Income Applicable to Common Shareholders',
#        'Net Income-Cont. Operations', 'Net Receivables', 'Non-Recurring Items',
#        'Operating Income', 'Operating Margin', 'Other Assets',
#        'Other Current Assets', 'Other Current Liabilities', 'Other Equity',
#        'Other Financing Activities', 'Other Investing Activities',
#        'Other Liabilities', 'Other Operating Activities',
#        'Other Operating Items', 'Pre-Tax Margin', 'Pre-Tax ROE',
#        'Profit Margin', 'Quick Ratio', 'Research and Development',
#        'Retained Earnings', 'Sale and Purchase of Stock',
#        'Sales, General and Admin.',
#        'Short-Term Debt / Current Portion of Long-Term Debt',
#        'Short-Term Investments', 'Total Assets', 'Total Current Assets',
#        'Total Current Liabilities', 'Total Equity', 'Total Liabilities',
#        'Total Liabilities & Equity', 'Total Revenue', 'Treasury Stock',
#        'For Year', 'Earnings Per Share', 'Estimated Shares Outstanding'],
#       dtype='object')

# %%
data.isnull().sum().sort_values(ascending = False)
# Out:
# Quick Ratio                     299
# Cash Ratio                      299
# Current Ratio                   299
# Estimated Shares Outstanding    219
# Earnings Per Share              219
#                                ...
# Intangible Assets                 0
# Income Tax                        0
# Gross Profit                      0
# Gross Margin                      0
# Net Cash Flows-Financing          0
# Length: 79, dtype: int64

# %%
data_cleaner = data.copy()
# Dropping columns based off of knowledge and/or null values
data_cleaner.drop(labels=['Unnamed: 0', 'Period Ending', 'For Year', 'Net Income Adjustments', 'Net Income Applicable to Common Shareholders','Net Income-Cont. Operations',
                         'Earnings Before Interest and Tax', 'Earnings Before Tax', 'Misc. Stocks', 'Net Cash Flow', 'Retained Earnings', 'Sale and Purchase of Stock',
                        'Total Liabilities & Equity', 'Treasury Stock', 'Earnings Per Share', 'Estimated Shares Outstanding', 'Cash Ratio', 'Current Ratio', 'Quick Ratio', 'Total Current Liabilities'], axis=1, inplace = True)

# %%
data_cleaner.isnull().sum().sort_values(ascending = False).head()
# Out:
# Ticker Symbol               0
# Period Ending               0
# Net Cash Flows-Financing    0
# Net Cash Flows-Investing    0
# Net Income                  0
# dtype: int64

# %%
for column_name in data_cleaner.columns:
    column = data_cleaner[column_name]
    # Get the count of Zeros in column 
    count = (column == 0).sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  Ticker Symbol  is :  0
# Count of zeros in column  Accounts Payable  is :  46
# Count of zeros in column  Accounts Receivable  is :  193
# Count of zeros in column  Add'l income/expense items  is :  305
# Count of zeros in column  After Tax ROE  is :  7
# Count of zeros in column  Capital Expenditures  is :  67
# Count of zeros in column  Capital Surplus  is :  257
# Count of zeros in column  Cash and Cash Equivalents  is :  0
# Count of zeros in column  Changes in Inventories  is :  640
# Count of zeros in column  Common Stocks  is :  101
# Count of zeros in column  Cost of Revenue  is :  107
# Count of zeros in column  Deferred Asset Charges  is :  1032
# Count of zeros in column  Deferred Liability Charges  is :  577
# Count of zeros in column  Depreciation  is :  13
# Count of zeros in column  Effect of Exchange Rate  is :  589
# Count of zeros in column  Equity Earnings/Loss Unconsolidated Subsidiary  is :  1239
# Count of zeros in column  Fixed Assets  is :  51
# Count of zeros in column  Goodwill  is :  371
# Count of zeros in column  Gross Margin  is :  71
# Count of zeros in column  Gross Profit  is :  71
# Count of zeros in column  Income Tax  is :  29
# Count of zeros in column  Intangible Assets  is :  524
# Count of zeros in column  Interest Expense  is :  269
# Count of zeros in column  Inventory  is :  550
# Count of zeros in column  Investments  is :  363
# Count of zeros in column  Liabilities  is :  45
# Count of zeros in column  Long-Term Debt  is :  156
# Count of zeros in column  Long-Term Investments  is :  746
# Count of zeros in column  Minority Interest  is :  839
# Count of zeros in column  Net Borrowings  is :  109
# Count of zeros in column  Net Cash Flow-Operating  is :  0
# Count of zeros in column  Net Cash Flows-Financing  is :  1
# Count of zeros in column  Net Cash Flows-Investing  is :  0
# Count of zeros in column  Net Income  is :  0
# Count of zeros in column  Net Receivables  is :  99
# Count of zeros in column  Non-Recurring Items  is :  1002
# Count of zeros in column  Operating Income  is :  71
# Count of zeros in column  Operating Margin  is :  80
# Count of zeros in column  Other Assets  is :  125
# Count of zeros in column  Other Current Assets  is :  330
# Count of zeros in column  Other Current Liabilities  is :  686
# Count of zeros in column  Other Equity  is :  59
# Count of zeros in column  Other Financing Activities  is :  543
# Count of zeros in column  Other Investing Activities  is :  79
# Count of zeros in column  Other Liabilities  is :  137
# Count of zeros in column  Other Operating Activities  is :  69
# Count of zeros in column  Other Operating Items  is :  747
# Count of zeros in column  Pre-Tax Margin  is :  12
# Count of zeros in column  Pre-Tax ROE  is :  12
# Count of zeros in column  Profit Margin  is :  14
# Count of zeros in column  Research and Development  is :  1317
# Count of zeros in column  Sales, General and Admin.  is :  71
# Count of zeros in column  Short-Term Debt / Current Portion of Long-Term Debt  is :  360
# Count of zeros in column  Short-Term Investments  is :  1111
# Count of zeros in column  Total Assets  is :  0
# Count of zeros in column  Total Current Assets  is :  299
# Count of zeros in column  Total Equity  is :  0
# Count of zeros in column  Total Liabilities  is :  0
# Count of zeros in column  Total Revenue  is :  0

# %% [markdown]
# Sometimes a lot of 0s is okay if it makes sense in the context of the variable

# %%
from sklearn.model_selection import train_test_split
# separate train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    data_cleaner.drop(labels=['Ticker Symbol', 'Net Income'], axis=1),
    data_cleaner['Net Income'],
    test_size=0.20,
    random_state=23)

# %%
train = pd.concat([X_train, y_train], axis = 1)

# %%
train.corrwith(train['Net Income']).abs().sort_values(ascending = False)
# Out:
# Net Income                                             1.000000
# Operating Income                                       0.915662
# Income Tax                                             0.890645
# Net Cash Flow-Operating                                0.827232
# Gross Profit                                           0.775077
# Total Revenue                                          0.707769
# Total Equity                                           0.705667
# Sales, General and Admin.                              0.618690
# Total Current Assets                                   0.603381
# Depreciation                                           0.600202
# Accounts Payable                                       0.577577
# Cost of Revenue                                        0.531961
# Capital Expenditures                                   0.520046
# Net Receivables                                        0.516953
# Net Cash Flows-Investing                               0.500887
# Other Current Assets                                   0.496438
# Research and Development                               0.463999
# Total Assets                                           0.452610
# Equity Earnings/Loss Unconsolidated Subsidiary         0.443913
# Fixed Assets                                           0.443802
# Goodwill                                               0.419510
# Short-Term Investments                                 0.413655
# Investments                                            0.413092
# Total Liabilities                                      0.407477
# Deferred Liability Charges                             0.404966
# Long-Term Debt                                         0.394655
# Long-Term Investments                                  0.372885
# Add'l income/expense items                             0.372451
# Common Stocks                                          0.366600
# Cash and Cash Equivalents                              0.364733
# Other Current Liabilities                              0.349881
# Capital Surplus                                        0.335561
# Short-Term Debt / Current Portion of Long-Term Debt    0.310707
# Other Operating Items                                  0.289986
# Interest Expense                                       0.285527
# Intangible Assets                                      0.265092
# Inventory                                              0.256302
# Other Equity                                           0.245323
# Minority Interest                                      0.236089
# Other Financing Activities                             0.208624
# Net Borrowings                                         0.206143
# Other Assets                                           0.172474
# Effect of Exchange Rate                                0.161796
# Changes in Inventories                                 0.142662
# Deferred Asset Charges                                 0.125531
# Liabilities                                            0.113030
# Other Liabilities                                      0.091760
# Operating Margin                                       0.051347
# Net Cash Flows-Financing                               0.050867
# Accounts Receivable                                    0.040553
# Non-Recurring Items                                    0.035623
# Other Investing Activities                             0.033158
# Gross Margin                                           0.027956
# Pre-Tax Margin                                         0.016968
# Pre-Tax ROE                                            0.016707
# After Tax ROE                                          0.016236
# Profit Margin                                          0.011353
# Other Operating Activities                             0.001003
# dtype: float64

# %%
sns.scatterplot(x = 'Profit Margin', y = 'Net Income', data = train)
# Out:
# <AxesSubplot:xlabel='Profit Margin', ylabel='Net Income'>

# %%
data_cleaner[data_cleaner['Profit Margin'] > 100]
# Out:
#      Ticker Symbol  Accounts Payable  Accounts Receivable  \
# 139            APA      6.180000e+08         6.630000e+08
# 305            CHK      1.045000e+09         1.186000e+09
# 379           COTY      2.630000e+05         2.750000e+05
# 381           COTY      1.556900e+07        -2.979000e+06
# 514            DVN      9.060000e+08         0.000000e+00
# 1017           MAC      1.003118e+09        -1.412600e+07
# 1155           NFX      6.320000e+08         8.300000e+07
# 1477           SWN      6.790000e+08         2.030000e+08
# 1660          VRTX      2.808700e+08         7.428000e+06
# 1732           XEC      3.966360e+08         1.866990e+08
# 1763          YHOO      4.178020e+09         2.927800e+07
#
#       Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# 139                -1.700000e+07          917.0         -5.178000e+09
# 305                 1.340000e+08          687.0         -3.771000e+09
# 379                 2.200000e+04           79.0         -5.000000e+04
# 381                -5.466900e+07          134.0         -8.960000e+05
# 514                -2.400000e+07          205.0         -6.415000e+09
# 1017                1.477535e+09           27.0         -2.006450e+08
# 1155                2.450000e+08          244.0         -1.745000e+09
# 1477                3.000000e+08          200.0         -1.798000e+09
# 1660                3.040000e+07           69.0         -5.120100e+07
# 1732                2.482200e+07           86.0         -1.049636e+09
# 1763                1.046733e+10           19.0         -4.130190e+08
#
#       Capital Surplus  Cash and Cash Equivalents  Changes in Inventories  \
# 139      1.246700e+10               1.467000e+09              21000000.0
# 305      1.240300e+10               8.250000e+08                     0.0
# 379      1.024700e+07               3.060000e+05                 15000.0
# 381      7.482800e+07               3.303000e+06             -12364000.0
# 514      4.996000e+09               2.310000e+09                     0.0
# 1017     5.041797e+09               9.843700e+07                     0.0
# 1155     2.436000e+09               5.000000e+06              -2000000.0
# 1477     3.409000e+09               1.500000e+07               4000000.0
# 1660     5.777154e+09               6.336770e+08             -16469000.0
# 1732     2.762976e+09               7.793820e+08                     0.0
# 1763     8.499475e+09               2.664098e+09                     0.0
#
#       Common Stocks  ...  Profit Margin  Research and Development  \
# 139     257000000.0  ...          369.0              0.000000e+00
# 305       7000000.0  ...          115.0              0.000000e+00
# 379         12000.0  ...          239.0              3.000000e+04
# 381         37000.0  ...          104.0              0.000000e+00
# 514      42000000.0  ...          110.0              0.000000e+00
# 1017      1582000.0  ...          136.0              0.000000e+00
# 1155      2000000.0  ...          216.0              0.000000e+00
# 1477      4000000.0  ...          145.0              0.000000e+00
# 1660      2385000.0  ...          127.0              8.555060e+08
# 1732       948000.0  ...          166.0              0.000000e+00
# 1763       945000.0  ...          163.0              1.156386e+09
#
#       Sales, General and Admin.  \
# 139                7.910000e+08
# 305                3.340000e+08
# 379                3.940000e+06
# 381                2.585300e+07
# 514                7.741000e+09
# 1017               2.941200e+07
# 1155               5.204000e+09
# 1477               1.208000e+09
# 1660               3.054090e+08
# 1732               1.798670e+08
# 1763               1.770710e+09
#
#       Short-Term Debt / Current Portion of Long-Term Debt  \
# 139                                                 0.0
# 305                                         421000000.0
# 379                                                 0.0
# 381                                           2000000.0
# 514                                         976000000.0
# 1017                                                0.0
# 1155                                         13000000.0
# 1477                                          4000000.0
# 1660                                         32012000.0
# 1732                                                0.0
# 1763                                                0.0
#
#       Short-Term Investments  Total Assets  Total Current Assets  \
# 139             0.000000e+00  1.884200e+10          3.752000e+09
# 305             0.000000e+00  1.735700e+10          2.480000e+09
# 379             5.390000e+06  7.188000e+06          6.639000e+06
# 381             0.000000e+00  2.168950e+08          4.865800e+07
# 514             0.000000e+00  2.945100e+10          4.021000e+09
# 1017            0.000000e+00  1.312178e+10          0.000000e+00
# 1155            0.000000e+00  4.768000e+09          6.250000e+08
# 1477            0.000000e+00  8.110000e+09          3.930000e+08
# 1660            7.618470e+08  2.334679e+09          1.546511e+09
# 1732            0.000000e+00  5.243286e+09          1.077930e+09
# 1763            5.327412e+09  6.170734e+10          9.444421e+09
#
#       Total Equity  Total Liabilities  Total Revenue
# 139   2.566000e+09       1.627600e+10   6.383000e+09
# 305   2.138000e+09       1.496000e+10   1.276400e+10
# 379   4.611000e+06       2.577000e+06   1.514000e+06
# 381  -7.713800e+07       2.940330e+08   9.964200e+07
# 514   7.049000e+09       2.240200e+10   1.314500e+10
# 1017  5.640120e+09       7.481658e+09   1.105247e+09
# 1155  1.379000e+09       3.389000e+09   1.557000e+09
# 1477  2.282000e+09       5.828000e+09   3.133000e+09
# 1660  1.075006e+09       1.259673e+09   5.804150e+08
# 1732  2.797678e+09       2.445608e+09   1.452619e+09
# 1763  3.874184e+10       2.296550e+10   4.618133e+09
#
# [11 rows x 59 columns]

# %% [markdown]
# Shouldn't be able to have profit margin greater than 100%

# %%
sns.scatterplot(x = 'Pre-Tax Margin', y = 'Net Income', data = train)
# Out:
# <AxesSubplot:xlabel='Pre-Tax Margin', ylabel='Net Income'>

# %%
sns.scatterplot(x = 'Accounts Payable', y = 'Net Income', data = train)
# Out:
# <AxesSubplot:xlabel='Accounts Payable', ylabel='Net Income'>

# %%
sns.scatterplot(x = 'Research and Development', y = 'Net Income', data = train)
# Out:
# <AxesSubplot:xlabel='Research and Development', ylabel='Net Income'>

# %% [markdown]
# Consider turning R&D into a categorical variable (1 if non-zero, 0 otherwise)

# %%
sns.scatterplot(x = 'Short-Term Debt / Current Portion of Long-Term Debt', y = 'Net Income', data = train)
# Out:
# <AxesSubplot:xlabel='Short-Term Debt / Current Portion of Long-Term Debt', ylabel='Net Income'>

# %%
train.corrwith(train['Net Income']).sort_values(ascending = False)
# Out:
# Net Income                                             1.000000
# Operating Income                                       0.915662
# Income Tax                                             0.890645
# Net Cash Flow-Operating                                0.827232
# Gross Profit                                           0.775077
# Total Revenue                                          0.707769
# Total Equity                                           0.705667
# Sales, General and Admin.                              0.618690
# Total Current Assets                                   0.603381
# Depreciation                                           0.600202
# Accounts Payable                                       0.577577
# Cost of Revenue                                        0.531961
# Net Receivables                                        0.516953
# Other Current Assets                                   0.496438
# Research and Development                               0.463999
# Total Assets                                           0.452610
# Equity Earnings/Loss Unconsolidated Subsidiary         0.443913
# Fixed Assets                                           0.443802
# Goodwill                                               0.419510
# Short-Term Investments                                 0.413655
# Total Liabilities                                      0.407477
# Deferred Liability Charges                             0.404966
# Long-Term Debt                                         0.394655
# Long-Term Investments                                  0.372885
# Add'l income/expense items                             0.372451
# Common Stocks                                          0.366600
# Cash and Cash Equivalents                              0.364733
# Other Current Liabilities                              0.349881
# Capital Surplus                                        0.335561
# Short-Term Debt / Current Portion of Long-Term Debt    0.310707
# Other Operating Items                                  0.289986
# Interest Expense                                       0.285527
# Intangible Assets                                      0.265092
# Inventory                                              0.256302
# Minority Interest                                      0.236089
# Other Financing Activities                             0.208624
# Net Borrowings                                         0.206143
# Other Assets                                           0.172474
# Deferred Asset Charges                                 0.125531
# Liabilities                                            0.113030
# Other Liabilities                                      0.091760
# Pre-Tax Margin                                         0.016968
# Profit Margin                                          0.011353
# Other Operating Activities                            -0.001003
# After Tax ROE                                         -0.016236
# Pre-Tax ROE                                           -0.016707
# Gross Margin                                          -0.027956
# Other Investing Activities                            -0.033158
# Non-Recurring Items                                   -0.035623
# Accounts Receivable                                   -0.040553
# Net Cash Flows-Financing                              -0.050867
# Operating Margin                                      -0.051347
# Changes in Inventories                                -0.142662
# Effect of Exchange Rate                               -0.161796
# Other Equity                                          -0.245323
# Investments                                           -0.413092
# Net Cash Flows-Investing                              -0.500887
# Capital Expenditures                                  -0.520046
# dtype: float64

# %%
from sklearn.linear_model import Lasso
alpha_lasso = [1, 10, 100, 1000, 10000, 10000000000000]

# %%
# Defining a function which will fit lasso regression model, plot the results, and return the coefficient
def lasso_regression(train_x, train_y, test_x, test_y, alpha, models_to_plot={}):
    
    #fit the model
    
    
    if alpha == 0:
        ls = LinearRegression()    
    else:
        ls = Lasso(alpha=alpha, max_iter=10000, tol=0.1)
    lassoreg=make_pipeline(StandardScaler(with_mean=False), ls)
    lassoreg.fit(train_x, train_y)
    train_y_pred = lassoreg.predict(train_x)
    test_y_pred = lassoreg.predict(test_x)
        
        
    
    #check if a plot is to be made for the entered alpha
    if alpha in models_to_plot:
        plt.subplot(models_to_plot[alpha])
        # plt_tight_layout()
        plt.plot(train_x[:, 0:1], train_y_pred)
        plt.plot(train_x[:, 0:1], train_y, '.')
        
        plt.title('Plot for alpha: %.3g'%alpha)
        
    #return the result in pre-defined format
    mrss_train = sum((train_y_pred - train_y)**2)/train_x.shape[0]
    ret = [mrss_train]
    
    mrss_test = sum((test_y_pred - test_y)**2)/test_x.shape[0]
    ret.extend([mrss_test])
    
    ret.extend([ls.intercept_])
    ret.extend(ls.coef_)
    
    return ret

# %%
X_train.shape
# Out:
# (1424, 58)

# %%
#initialize a dataframe to store the coefficient:
col = ['mrss_train', 'mrss_test', 'intercept'] + ['coef_VaR_%d'%i for i in range(1, 58)]
ind = ['alpha_%.2g'%alpha_lasso[i] for i in range(0, 6)]
coef_matrix_lasso = pd.DataFrame(index=ind, columns=col)

# %%
for i in range(6):
    coef_matrix_lasso.iloc[i,] = lasso_regression(X_train, y_train, X_test, y_test, alpha_lasso[i])

# %%
coef_matrix_lasso
# Out:
#                          mrss_train               mrss_test  \
# alpha_1       1323267881808799744.0   2246287409619590400.0
# alpha_10      1323267837259757568.0   2246287462739090944.0
# alpha_1e+02   1323267391770100992.0   2246287993935537408.0
# alpha_1e+03   1323262936944443136.0   2246293306043928832.0
# alpha_1e+04   1323218395781874688.0   2246346441524532992.0
# alpha_1e+13  16969638265601212416.0  11831931851130202112.0
#
#                      intercept         coef_VaR_1        coef_VaR_2  \
# alpha_1       358691577.401411   1713334100.98991  -310238568.82792
# alpha_10      358691554.172868  1713334074.166409 -310238537.186157
# alpha_1e+02   358691321.887443  1713333805.931403 -310238220.768533
# alpha_1e+03   358688999.033195  1713331123.581338 -310235056.592288
# alpha_1e+04   358665770.490717   1713304300.08069 -310203414.829847
# alpha_1e+13  1744167131.320225                0.0              -0.0
#
#                    coef_VaR_3       coef_VaR_4         coef_VaR_5  \
# alpha_1      267346042.358405 -46432180.598832  -1050008728.72264
# alpha_10       267346025.4275 -46432119.671011 -1050008662.090458
# alpha_1e+02  267345856.118453 -46431510.392806 -1050007995.768632
# alpha_1e+03  267344163.027978 -46425417.610755 -1050001332.550372
# alpha_1e+04  267327232.123226 -46364489.790242  -1049934700.36777
# alpha_1e+13               0.0             -0.0               -0.0
#
#                    coef_VaR_6        coef_VaR_7  ...       coef_VaR_48  \
# alpha_1      776434340.805233  -168161242.62214  ...  305223162.916631
# alpha_10     776434326.676415 -168161153.121695  ...  305223141.724081
# alpha_1e+02   776434185.38825 -168160258.117256  ...   305222929.79858
# alpha_1e+03  776432772.506588 -168151308.072862  ...  305220810.543576
# alpha_1e+04  776418643.689972 -168061807.628918  ...  305199617.993537
# alpha_1e+13               0.0               0.0  ...               0.0
#
#                   coef_VaR_49       coef_VaR_50       coef_VaR_51  \
# alpha_1      184582242.435109 -856188648.372422  650513677.936191
# alpha_10     184582250.217811 -856188606.846467  650513618.389501
# alpha_1e+02  184582328.044829 -856188191.586915  650513022.922605
# alpha_1e+03  184583106.315011  -856184038.99139  650507068.253635
# alpha_1e+04  184590889.016836 -856142513.036149  650447521.563942
# alpha_1e+13               0.0               0.0               0.0
#
#                   coef_VaR_52      coef_VaR_53       coef_VaR_54  \
# alpha_1      307289302.645996 -43943107.465296 -271658806.588524
# alpha_10     307289299.666694 -43943059.043393 -271658780.334424
# alpha_1e+02  307289269.873674 -43942574.824363  -271658517.79343
# alpha_1e+03  307288971.943479 -43937732.634055 -271655892.383485
# alpha_1e+04  307285992.641522 -43889310.730989  -271629638.28404
# alpha_1e+13               0.0              0.0               0.0
#
#                  coef_VaR_55      coef_VaR_56       coef_VaR_57
# alpha_1     -39137526.632807  57886272.228848 -442255714.884147
# alpha_10    -39137531.313322  57886241.381079 -442255721.301443
# alpha_1e+02 -39137578.118475  57885932.903385 -442255785.474403
# alpha_1e+03  -39138046.17001  57882848.126446 -442256427.204002
# alpha_1e+04 -39142726.685359  57852000.357056 -442262844.499989
# alpha_1e+13              0.0              0.0               0.0
#
# [6 rows x 60 columns]

# %% [markdown]
# Possible that some variables with low correlation are still related but not linearly
